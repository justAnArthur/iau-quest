# %% [markdown]
# # Fáza 1

# %% [markdown]
# ## 1.1 Základný opis dát spolu s ich charakteristikami

# %% [markdown]
# ### 1.1.A Analýza štruktúr dát ako súbory (štruktúry a vzťahy, počet, typy, …), záznamy (štruktúry, počet záznamov, počet atribútov, typy, …)

# %%
import pandas as pd

# %% [markdown]
# K dispozícii máme štyri súbory csv:

# %%
connections = pd.read_csv('data/connections.csv', delimiter='\t')
connections
# Out:
#                         ts                 imei  mwra  c.katana  c.dogalize  \
# 0      2018-05-05 10:00:00  8630330696303481172   1.0   9.29393     9.65293
# 1      2018-05-05 10:01:00  3590433799317662097   0.0   9.87107     6.65895
# 2      2018-05-05 10:02:00  3590433799317661123   0.0  15.31239     5.01324
# 3      2018-05-05 10:03:00  8630330696303481909   1.0   8.23151     9.76082
# 4      2018-05-05 10:04:00  8630330696303481701   1.0   8.02947    10.25168
# ...                    ...                  ...   ...       ...         ...
# 15150  2018-05-11 15:20:00   863033069630348768   1.0  13.27809    11.42837
# 15151  2018-05-09 12:13:00  8630330696303481834   1.0  11.68512    11.64407
# 15152  2018-05-15 10:18:00  8630330696303482147   1.0  10.56641    14.11005
# 15153  2018-05-09 10:36:00   359043379931766494   1.0  11.31192    13.64240
# 15154  2018-05-06 07:59:00  8630330696303481271   1.0   8.00197    11.48360
#
# ...

# %%
connections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15155 entries, 0 to 15154
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ts                 15155 non-null  object
#  1   imei               15155 non-null  int64
#  2   mwra               15155 non-null  float64
#  3   c.katana           15155 non-null  float64
#  4   c.dogalize         15155 non-null  float64
#  5   c.android.youtube  15155 non-null  float64
#  6   c.android.chrome   15155 non-null  float64
#  7   c.android.gm       15155 non-null  float64
#  8   c.raider           15155 non-null  float64
#  9   c.UCMobile.x86     15155 non-null  float64
#  10  c.updateassist     15155 non-null  float64
#  11  c.UCMobile.intl    15155 non-null  float64
#  12  c.android.vending  15155 non-null  float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# ^ „connections.csv“– Seems to be a list of connections that is related to a certain electronic device with `imei` number.

# %%
devices = pd.read_csv('data/devices.csv', delimiter='\t')
devices
# Out:
#       latitude  longitude     store_name code          location  \
# 0     61.78491   34.34691   Petrozavodsk   RU     Europe/Moscow
# 1     28.98002   77.70636         Meerut   IN      Asia/Kolkata
# 2     23.90280   89.11943        Kushtia   BD        Asia/Dhaka
# 3     -8.99167  125.21972        Maliana   TL         Asia/Dili
# 4     33.08014  -83.23210  Milledgeville   US  America/New_York
# ...        ...        ...            ...  ...               ...
# 2970  44.80477   -0.59543        Talence   FR      Europe/Paris
# 2971  51.65333    5.28750          Vught   NL  Europe/Amsterdam
# 2972  33.50921 -111.89903     Scottsdale   US   America/Phoenix
# 2973  50.80019    7.20769       Siegburg   DE     Europe/Berlin
# 2974  35.30889  139.55028       Kamakura   JP        Asia/Tokyo
#
#                      imei
# 0     3590433799317661040
# 1     3590433799317661263
# 2      359043379931766866
# 3     3590433799317661073
# 4     8630330696303482311
# ...                   ...
# ...

# %%
devices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2975 entries, 0 to 2974
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    2975 non-null   float64
#  1   longitude   2975 non-null   float64
#  2   store_name  2975 non-null   object
#  3   code        2968 non-null   object
#  4   location    2975 non-null   object
#  5   imei        2975 non-null   int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 139.6+ KB

# %% [markdown]
# ^ „devices.csv“– Contains information about electronic devices with `imei` number with its location and (likely) in which store it is (installed).

# %%
processes = pd.read_csv('data/processes.csv', delimiter='\t')
processes
# Out:
#                         ts                 imei  mwra  p.system  p.android.gm  \
# 0      2018-05-05 10:00:00  8630330696303481172   1.0  10.85162       5.76758
# 1      2018-05-05 10:01:00  3590433799317662097   0.0  11.19103      11.05400
# 2      2018-05-05 10:02:00  3590433799317661123   0.0  10.13556       8.68557
# 3      2018-05-05 10:03:00  8630330696303481909   1.0   7.20268       6.00790
# 4      2018-05-05 10:04:00  8630330696303481701   1.0   9.63418       9.27475
# ...                    ...                  ...   ...       ...           ...
# 15150  2018-05-11 15:20:00   863033069630348768   1.0  10.02363       7.56187
# 15151  2018-05-09 12:13:00  8630330696303481834   1.0   6.89386      10.70348
# 15152  2018-05-15 10:18:00  8630330696303482147   1.0   8.68681       5.75297
# 15153  2018-05-09 10:36:00   359043379931766494   1.0   4.16575       8.59649
# 15154  2018-05-06 07:59:00  8630330696303481271   1.0   8.57569       7.22024
#
# ...

# %%
processes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15155 entries, 0 to 15154
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ts                          15155 non-null  object
#  1   imei                        15155 non-null  int64
#  2   mwra                        15155 non-null  float64
#  3   p.system                    15155 non-null  float64
#  4   p.android.gm                15155 non-null  float64
#  5   p.android.settings          15155 non-null  float64
#  6   p.android.chrome            15155 non-null  float64
#  7   p.android.packageinstaller  15155 non-null  float64
#  8   p.android.documentsui       15155 non-null  float64
#  9   p.android.externalstorage   15155 non-null  float64
#  10  p.android.vending           15155 non-null  float64
#  11  p.olauncher                 15155 non-null  float64
#  12  p.android.defcontainer      15155 non-null  float64
# ...

# %% [markdown]
# ^ „processes.csv“– Contains information about processes that are running on a certain electronic device with `imei` number.

# %%
profiles = pd.read_csv('data/profiles.csv', delimiter='\t')
profiles
# Out:
#                  name                           company          ssn  \
# 0     Elizabeth Sloan            Jackson, Quinn and Cox  602-11-8872
# 1         Marie Smith          Glover, Jones and Hughes  260-99-5834
# 2     Michelle Martin    Camacho, Phillips and Phillips  874-79-4212
# 3         John Cannon                         Craig Ltd  058-93-8409
# 4       Denise Barnes         Hoover, Austin and Nguyen  544-70-5957
# ...               ...                               ...          ...
# 2520    Maria Sanders          Ingram, Juarez and Clark  091-49-1693
# 2521      Dylan Moore                      Cohen-Daniel  566-77-9989
# 2522  Tamara Robinson  Martinez, Griffin and Washington  318-57-9519
# 2523    Bill Peterson                      Torres-Brown  374-14-3768
# 2524   Karen Chambers                        Hunter LLC  255-72-6258
#
#                                      current_location                 imei  \
# ...

# %%
profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2525 entries, 0 to 2524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2525 non-null   object
#  1   company           2525 non-null   object
#  2   ssn               2525 non-null   object
#  3   current_location  2399 non-null   object
#  4   imei              2525 non-null   int64
#  5   address           2146 non-null   object
#  6   birthdate         1389 non-null   object
#  7   registration      2525 non-null   object
#  8   user_id           2525 non-null   int64
#  9   username          2525 non-null   object
#  10  mail              2525 non-null   object
#  11  job               757 non-null    object
# dtypes: int64(2), object(10)
# memory usage: 236.8+ KB

# %% [markdown]
# ^ „profiles.csv“– Contains information about profiles that are related to a certain electronic device with `imei` number.

# %% [markdown]
# ### 1.1.B Analýza jednotlivých atribútov: pre zvolené významné atribút

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Let's analyze next major attributes:
#
# - `connections`:
#     -
# - `devices`:
# - `processes`:
# - `profiles`:
